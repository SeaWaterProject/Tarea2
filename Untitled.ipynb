# %%
import pandas as pd

humanLink="https://github.com/SeaWaterProject/PC2/raw/main/dataUN%20-%20HDR21-22_Statistical_Annex_HDI_Table%20(1).csv"

human=pd.read_csv(humanLink)

human
# Out:
#          Back Table 1. Human Development Index and its components  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                              NaN         NaN                       NaN
# 1                              NaN         NaN                      SDG3
# 2                              NaN         NaN                       NaN
# 3    Human Development Index (HDI)         NaN  Life expectancy at birth
# 4                            Value         NaN                   (years)
# ..                             ...         ...                       ...
# 271                            NaN         NaN                       NaN
# 272                            NaN         NaN                       NaN
# 273                            NaN         NaN                       NaN
# 274                            NaN         NaN                       NaN
# 275                            NaN         NaN                       NaN
#
#     Unnamed: 5                   Unnamed: 6 Unnamed: 7  \
# 0          NaN                          NaN        NaN
# 1          NaN                       SDG4.3        NaN
# 2          NaN                          NaN        NaN
# 3          NaN  Expected years of schooling        NaN
# 4          NaN                      (years)        NaN
# ..         ...                          ...        ...
# 271        NaN                          NaN        NaN
# 272        NaN                          NaN        NaN
# 273        NaN                          NaN        NaN
# 274        NaN                          NaN        NaN
# 275        NaN                          NaN        NaN
#
#                   Unnamed: 8 Unnamed: 9  \
# 0                        NaN        NaN
# 1                     SDG4.4        NaN
# 2                        NaN        NaN
# 3    Mean years of schooling        NaN
# 4                    (years)        NaN
# ..                       ...        ...
# 271                      NaN        NaN
# 272                      NaN        NaN
# 273                      NaN        NaN
# 274                      NaN        NaN
# 275                      NaN        NaN
#
#                                 Unnamed: 10 Unnamed: 11  \
# 0                                       NaN         NaN
# 1                                    SDG8.5         NaN
# 2                                       NaN         NaN
# 3    Gross national income (GNI) per capita         NaN
# 4                              (2017 PPP $)         NaN
# ..                                      ...         ...
# 271                                     NaN         NaN
# 272                                     NaN         NaN
# 273                                     NaN         NaN
# 274                                     NaN         NaN
# 275                                     NaN         NaN
#
#                             Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0                                   NaN         NaN         NaN
# 1                                   NaN         NaN         NaN
# 2                                   NaN         NaN         NaN
# 3    GNI per capita rank minus HDI rank         NaN    HDI rank
# 4                                   NaN         NaN         NaN
# ..                                  ...         ...         ...
# 271                                 NaN         NaN         NaN
# 272                                 NaN         NaN         NaN
# 273                                 NaN         NaN         NaN
# 274                                 NaN         NaN         NaN
# 275                                 NaN         NaN         NaN
#
# [276 rows x 15 columns]

# %%
#LIMPIEZA

#renombre de columnas
newHumanNames={'Back':'HDI_rank','Table 1. Human Development Index and its components':'Country',"Unnamed: 2":"Value","Unnamed: 4":"Life_Expectancy","Unnamed: 6":"Exp_Years_School","Unnamed: 8":"Mean_Years_School","Unnamed: 10":"GNI_capita","Unnamed: 12":"GNI_HDI_RANK","Unnamed: 14":"HDI_RANK"}
human.rename(columns=newHumanNames,inplace=True)
human
# Out:
#      HDI_rank                                            Country  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                              Value  Unnamed: 3           Life_Expectancy  \
# 0                              NaN         NaN                       NaN
# 1                              NaN         NaN                      SDG3
# 2                              NaN         NaN                       NaN
# 3    Human Development Index (HDI)         NaN  Life expectancy at birth
# 4                            Value         NaN                   (years)
# ..                             ...         ...                       ...
# 271                            NaN         NaN                       NaN
# 272                            NaN         NaN                       NaN
# 273                            NaN         NaN                       NaN
# 274                            NaN         NaN                       NaN
# 275                            NaN         NaN                       NaN
#
#     Unnamed: 5             Exp_Years_School Unnamed: 7  \
# 0          NaN                          NaN        NaN
# 1          NaN                       SDG4.3        NaN
# 2          NaN                          NaN        NaN
# 3          NaN  Expected years of schooling        NaN
# 4          NaN                      (years)        NaN
# ..         ...                          ...        ...
# 271        NaN                          NaN        NaN
# 272        NaN                          NaN        NaN
# 273        NaN                          NaN        NaN
# 274        NaN                          NaN        NaN
# 275        NaN                          NaN        NaN
#
#            Mean_Years_School Unnamed: 9  \
# 0                        NaN        NaN
# 1                     SDG4.4        NaN
# 2                        NaN        NaN
# 3    Mean years of schooling        NaN
# 4                    (years)        NaN
# ..                       ...        ...
# 271                      NaN        NaN
# 272                      NaN        NaN
# 273                      NaN        NaN
# 274                      NaN        NaN
# 275                      NaN        NaN
#
#                                  GNI_capita Unnamed: 11  \
# 0                                       NaN         NaN
# 1                                    SDG8.5         NaN
# 2                                       NaN         NaN
# 3    Gross national income (GNI) per capita         NaN
# 4                              (2017 PPP $)         NaN
# ..                                      ...         ...
# 271                                     NaN         NaN
# 272                                     NaN         NaN
# 273                                     NaN         NaN
# 274                                     NaN         NaN
# 275                                     NaN         NaN
#
#                            GNI_HDI_RANK Unnamed: 13  HDI_RANK
# 0                                   NaN         NaN       NaN
# 1                                   NaN         NaN       NaN
# 2                                   NaN         NaN       NaN
# 3    GNI per capita rank minus HDI rank         NaN  HDI rank
# 4                                   NaN         NaN       NaN
# ..                                  ...         ...       ...
# 271                                 NaN         NaN       NaN
# 272                                 NaN         NaN       NaN
# 273                                 NaN         NaN       NaN
# 274                                 NaN         NaN       NaN
# 275                                 NaN         NaN       NaN
#
# [276 rows x 15 columns]

# %%
#quitar columnas
byeColumns=["HDI_rank","Unnamed: 3","Unnamed: 5","Unnamed: 7","Unnamed: 9","Unnamed: 11","Unnamed: 13","GNI_HDI_RANK","HDI_RANK"]

human.drop(columns=byeColumns,inplace=True)

# %%
#muestra de las primeras 10 filas
human.head(10)
# Out:
#                        Country                          Value  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN  Human Development Index (HDI)
# 4                      Country                          Value
# 5                          NaN                           2021
# 6  VERY HIGH HUMAN DEVELOPMENT                            NaN
# 7                  Switzerland                            962
# 8                       Norway                            961
# 9                      Iceland                            959
#
#             Life_Expectancy             Exp_Years_School  \
# 0                       NaN                          NaN
# 1                      SDG3                       SDG4.3
# 2                       NaN                          NaN
# 3  Life expectancy at birth  Expected years of schooling
# 4                   (years)                      (years)
# 5                      2021                         2021
# 6                       NaN                          NaN
# 7                      84.0                         16.5
# 8                      83.2                         18.2
# 9                      82.7                         19.2
#
#          Mean_Years_School                              GNI_capita
# 0                      NaN                                     NaN
# 1                   SDG4.4                                  SDG8.5
# 2                      NaN                                     NaN
# 3  Mean years of schooling  Gross national income (GNI) per capita
# 4                  (years)                            (2017 PPP $)
# 5                     2021                                    2021
# 6                      NaN                                     NaN
# 7                     13.9                                  66,933
# 8                     13.0                                  64,660
# 9                     13.8                                  55,782

# %%
#quitar filas
byeRows=[0,1,2,3,4,5,6,66,115,159]
human.drop(index=byeRows,inplace=True)

human
# Out:
#                                                Country Value Life_Expectancy  \
# 7                                          Switzerland   962            84.0
# 8                                               Norway   961            83.2
# 9                                              Iceland   959            82.7
# 10                              Hong Kong, China (SAR)   952            85.5
# 11                                           Australia   951            84.5
# ..                                                 ...   ...             ...
# 271                          Column 2: UNDESA (2022a).   NaN             NaN
# 272  Column 3: CEDLAS and World Bank (2022), ICF Ma...   NaN             NaN
# 273  Column 4: Barro and Lee (2018), ICF Macro Demo...   NaN             NaN
# 274  Column 5: IMF (2022), UNDESA (2022b), United N...   NaN             NaN
# 275  Column 6: Calculated based on data in columns ...   NaN             NaN
#
#     Exp_Years_School Mean_Years_School GNI_capita
# 7               16.5              13.9     66,933
# 8               18.2              13.0     64,660
# 9               19.2              13.8     55,782
# 10              17.3              12.2     62,607
# 11              21.1              12.7     49,238
# ..               ...               ...        ...
# 271              NaN               NaN        NaN
# 272              NaN               NaN        NaN
# 273              NaN               NaN        NaN
# 274              NaN               NaN        NaN
# 275              NaN               NaN        NaN
#
# [266 rows x 6 columns]

# %%
#quitar un rango de filas
human=human.drop(range(201,276))
human
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 7                 Switzerland   962            84.0             16.5
# 8                      Norway   961            83.2             18.2
# 9                     Iceland   959            82.7             19.2
# 10     Hong Kong, China (SAR)   952            85.5             17.3
# 11                  Australia   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 196                   Burundi   426            61.7             10.7
# 197  Central African Republic   404            53.9              8.0
# 198                     Niger   400            61.6              7.0
# 199                      Chad   394            52.5              8.0
# 200               South Sudan   385            55.0              5.5
#
#     Mean_Years_School GNI_capita
# 7                13.9     66,933
# 8                13.0     64,660
# 9                13.8     55,782
# 10               12.2     62,607
# 11               12.7     49,238
# ..                ...        ...
# 196               3.1        732
# 197               4.3        966
# 198               2.1      1,240
# 199               2.6      1,364
# 200               5.7        768
#
# [191 rows x 6 columns]

# %%
#ningun espacio en columnas
human.columns=human.columns.str.replace(r'\s','',regex=True)

# %%
#no spacios en string values (para varias columnas)
byeSpaces=lambda x: x.str.strip()
human.iloc[:,[0,5]]=human.iloc[:,[0,5]].apply(byeSpaces)

# %%
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 7 to 200
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            191 non-null    object
#  1   Value              188 non-null    object
#  2   Life_Expectancy    188 non-null    object
#  3   Exp_Years_School   188 non-null    object
#  4   Mean_Years_School  188 non-null    object
#  5   GNI_capita         188 non-null    object
# dtypes: object(6)
# memory usage: 10.4+ KB

# %%
#Cambiar las comas por puntos
human['GNI_capita']=human.GNI_capita.str.replace(",",'')
human
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 7                 Switzerland   962            84.0             16.5
# 8                      Norway   961            83.2             18.2
# 9                     Iceland   959            82.7             19.2
# 10     Hong Kong, China (SAR)   952            85.5             17.3
# 11                  Australia   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 196                   Burundi   426            61.7             10.7
# 197  Central African Republic   404            53.9              8.0
# 198                     Niger   400            61.6              7.0
# 199                      Chad   394            52.5              8.0
# 200               South Sudan   385            55.0              5.5
#
#     Mean_Years_School GNI_capita
# 7                13.9      66933
# 8                13.0      64660
# 9                13.8      55782
# 10               12.2      62607
# 11               12.7      49238
# ..                ...        ...
# 196               3.1        732
# 197               4.3        966
# 198               2.1       1240
# 199               2.6       1364
# 200               5.7        768
#
# [191 rows x 6 columns]

# %%
#FORMATEO

#tenemos duplicados?
human[human.duplicated(subset='Country')]
# Out:
# Empty DataFrame
# Columns: [Country, Value, Life_Expectancy, Exp_Years_School, Mean_Years_School, GNI_capita]
# Index: []

# %%
#Tenemos simbolos raros?
human[human.Country.str.contains(r'[^\w\s]')]
# Out:
#                                 Country Value Life_Expectancy  \
# 10               Hong Kong, China (SAR)   952            85.5
# 26                  Korea (Republic of)   925            83.7
# 83           Iran (Islamic Republic of)   774            73.9
# 88                Moldova (Republic of)   767            68.8
# 113                 Palestine, State of   715            73.5
# 126    Bolivia (Plurinational State of)   692            63.6
# 128  Venezuela (Bolivarian Republic of)   691            70.6
# 142    Micronesia (Federated States of)   628            70.7
# 148    Lao People's Democratic Republic   607            68.1
# 149                         Timor-Leste   607            67.7
# 152               Eswatini (Kingdom of)   597            57.1
# 167                       Côte d'Ivoire   550            58.6
# 169       Tanzania (United Republic of)   549            66.2
# 186                       Guinea-Bissau   483            59.7
# 188  Congo (Democratic Republic of the)   479            59.2
#
#     Exp_Years_School Mean_Years_School GNI_capita
# 10              17.3              12.2      62607
# 26              16.5              12.5      44501
# 83              14.6              10.6      13001
# 88              14.4              11.8      14875
# 113             13.4               9.9       6583
# 126             14.9               9.8       8111
# 128             12.8              11.1       4811
# 142             11.5               7.8       3696
# 148             10.1               5.4       7700
# 149             12.6               5.4       4461
# 152             13.7               5.6       7679
# 167             10.7               5.2       5217
# 169              9.2               6.4       2664
# 186             10.6               3.6       1908
# 188              9.8               7.0       1076

# %%
#Tenemos acentos en palabras?
human[human.Country.str.contains(r"\w*[\u00C0-\u01DA']\w*")]
# Out:
#                               Country Value Life_Expectancy Exp_Years_School  \
# 54                            Türkiye   838            76.0             18.3
# 148  Lao People's Democratic Republic   607            68.1             10.1
# 167                     Côte d'Ivoire   550            58.6             10.7
#
#     Mean_Years_School GNI_capita
# 54                8.6      31033
# 148               5.4       7700
# 167               5.2       5217

# %%
#solo ascii
from unidecode import unidecode

human['Country']=human.Country.apply(unidecode)

# %%
#creamos una nueva columna con valores en mayuscula
human_test=human.copy()
human_test['COUNTRYNAME']=human_test.Country.str.upper()
human_test
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 7                 Switzerland   962            84.0             16.5
# 8                      Norway   961            83.2             18.2
# 9                     Iceland   959            82.7             19.2
# 10     Hong Kong, China (SAR)   952            85.5             17.3
# 11                  Australia   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 196                   Burundi   426            61.7             10.7
# 197  Central African Republic   404            53.9              8.0
# 198                     Niger   400            61.6              7.0
# 199                      Chad   394            52.5              8.0
# 200               South Sudan   385            55.0              5.5
#
#     Mean_Years_School GNI_capita               COUNTRYNAME
# 7                13.9      66933               SWITZERLAND
# 8                13.0      64660                    NORWAY
# 9                13.8      55782                   ICELAND
# 10               12.2      62607    HONG KONG, CHINA (SAR)
# 11               12.7      49238                 AUSTRALIA
# ..                ...        ...                       ...
# 196               3.1        732                   BURUNDI
# 197               4.3        966  CENTRAL AFRICAN REPUBLIC
# 198               2.1       1240                     NIGER
# 199               2.6       1364                      CHAD
# 200               5.7        768               SOUTH SUDAN
#
# [191 rows x 7 columns]

# %%
#Mantenmos los nombres en mayusculas
human['Country']=human.Country.str.upper()
human
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 7                 SWITZERLAND   962            84.0             16.5
# 8                      NORWAY   961            83.2             18.2
# 9                     ICELAND   959            82.7             19.2
# 10     HONG KONG, CHINA (SAR)   952            85.5             17.3
# 11                  AUSTRALIA   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 196                   BURUNDI   426            61.7             10.7
# 197  CENTRAL AFRICAN REPUBLIC   404            53.9              8.0
# 198                     NIGER   400            61.6              7.0
# 199                      CHAD   394            52.5              8.0
# 200               SOUTH SUDAN   385            55.0              5.5
#
#     Mean_Years_School GNI_capita
# 7                13.9      66933
# 8                13.0      64660
# 9                13.8      55782
# 10               12.2      62607
# 11               12.7      49238
# ..                ...        ...
# 196               3.1        732
# 197               4.3        966
# 198               2.1       1240
# 199               2.6       1364
# 200               5.7        768
#
# [191 rows x 6 columns]

# %%
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 7 to 200
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            191 non-null    object
#  1   Value              188 non-null    object
#  2   Life_Expectancy    188 non-null    object
#  3   Exp_Years_School   188 non-null    object
#  4   Mean_Years_School  188 non-null    object
#  5   GNI_capita         188 non-null    object
# dtypes: object(6)
# memory usage: 10.4+ KB

# %%
#Cambiamos los valores de las columnas a valores numericos

human['Value']=pd.to_numeric(human.Value)
human['Life_Expectancy']=pd.to_numeric(human.Life_Expectancy)
human['Exp_Years_School']=pd.to_numeric(human.Exp_Years_School)
human['Mean_Years_School']=pd.to_numeric(human.Mean_Years_School)
human['GNI_capita']=pd.to_numeric(human.GNI_capita)
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 7 to 200
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            191 non-null    object
#  1   Value              188 non-null    float64
#  2   Life_Expectancy    188 non-null    float64
#  3   Exp_Years_School   188 non-null    float64
#  4   Mean_Years_School  188 non-null    float64
#  5   GNI_capita         188 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 10.4+ KB

# %%
human
# Out:
#                       Country  Value  Life_Expectancy  Exp_Years_School  \
# 7                 SWITZERLAND  962.0             84.0              16.5
# 8                      NORWAY  961.0             83.2              18.2
# 9                     ICELAND  959.0             82.7              19.2
# 10     HONG KONG, CHINA (SAR)  952.0             85.5              17.3
# 11                  AUSTRALIA  951.0             84.5              21.1
# ..                        ...    ...              ...               ...
# 196                   BURUNDI  426.0             61.7              10.7
# 197  CENTRAL AFRICAN REPUBLIC  404.0             53.9               8.0
# 198                     NIGER  400.0             61.6               7.0
# 199                      CHAD  394.0             52.5               8.0
# 200               SOUTH SUDAN  385.0             55.0               5.5
#
#      Mean_Years_School  GNI_capita
# 7                 13.9     66933.0
# 8                 13.0     64660.0
# 9                 13.8     55782.0
# 10                12.2     62607.0
# 11                12.7     49238.0
# ..                 ...         ...
# 196                3.1       732.0
# 197                4.3       966.0
# 198                2.1      1240.0
# 199                2.6      1364.0
# 200                5.7       768.0
#
# [191 rows x 6 columns]
